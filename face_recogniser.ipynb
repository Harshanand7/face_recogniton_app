# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshanand7/face_recogniton_app/blob/main/face_recogniser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown
import gdown

# %%
# below is the file id of the image which I had uploaded to my google drive
file_id = '12HkNorHn8pxLdNbqHBVMcscv6eiEfxQu'

# constructing the download URL
url = f'https://drive.google.com/uc?id={file_id}'

# specifying the output file name
output_img = 'img.png'

# downloading the  file from Google Drive
gdown.download(url, output_img, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12HkNorHn8pxLdNbqHBVMcscv6eiEfxQu
# To: /content/img.png
# 100%|██████████| 1.55M/1.55M [00:00<00:00, 85.1MB/s]
# 'img.png'

# %%
import cv2
import os
from google.colab.patches import cv2_imshow

# reading the input image

img = cv2.imread(output_img)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1338x753>

# %%
# loading the cascade model of opencv
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# converting into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# detecting faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

# creating a directory to save the faces
os.makedirs('faces', exist_ok=True)

# extracting and save each face
for i, (x, y, w, h) in enumerate(faces):
    face = img[y:y+h, x:x+w]
    face_filename = f'faces/face_{i+1}.jpg'
    cv2.imwrite(face_filename, face)
    cv2_imshow(face)
# Out:
# <PIL.Image.Image image mode=RGB size=27x27>
# <PIL.Image.Image image mode=RGB size=48x48>
# <PIL.Image.Image image mode=RGB size=36x36>
# <PIL.Image.Image image mode=RGB size=45x45>
# <PIL.Image.Image image mode=RGB size=39x39>
# <PIL.Image.Image image mode=RGB size=44x44>
# <PIL.Image.Image image mode=RGB size=47x47>
# <PIL.Image.Image image mode=RGB size=52x52>
# <PIL.Image.Image image mode=RGB size=38x38>
# <PIL.Image.Image image mode=RGB size=43x43>
# <PIL.Image.Image image mode=RGB size=44x44>
# <PIL.Image.Image image mode=RGB size=51x51>
# <PIL.Image.Image image mode=RGB size=52x52>
# <PIL.Image.Image image mode=RGB size=47x47>
# <PIL.Image.Image image mode=RGB size=52x52>
# <PIL.Image.Image image mode=RGB size=52x52>
# <PIL.Image.Image image mode=RGB size=51x51>
# <PIL.Image.Image image mode=RGB size=58x58>
# <PIL.Image.Image image mode=RGB size=46x46>
# <PIL.Image.Image image mode=RGB size=57x57>
# <PIL.Image.Image image mode=RGB size=49x49>
# ...

# %%
cv2.destroyAllWindows()
